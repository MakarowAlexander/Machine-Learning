# %% [markdown]
# # Вина «Vinho Verde»

# %% [markdown]
# Данные рассмотренные в этой работе, представляют информацию об вариантах красного вина португальской компании «Vinho Verde». Из-за вопросов конфиденциальности представлены только физико-химические (входные) и сенсорные (выходные) переменные, но отстутствуют данные о типах винограда, винной марке, цене продажи вина и т. д..

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# # ***Задание №1***

# %% [markdown]
# ## **Загружаем данные**

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'
data = pd.read_csv(url, sep = ';', engine = 'python')

# %% [markdown]
# ## **Смотрим, что появилось в переменной «data»**

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %% [markdown]
# ## **Тип переменной «data»**

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
print(data)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %% [markdown]
# ## **Вывод первых пяти строк таблицы**

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ## **Вывод последних пяти строк таблицы**

# %%
data.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %% [markdown]
# ## ** Число строк, столбцов**

# %%
print(data.shape)
# Out:
# (1599, 12)

# %% [markdown]
# Таблица содержит 1599 строк и 12 столбцов.

# %% [markdown]
# ## **Вывод названий столбцов**

# %%
print(data.columns)
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# ## **Объяснение выведенных данных.**

# %% [markdown]
# - **fixed acidity (кислотность)** - важнейший фактор, определяющий способность вина к длительному хранению и она ответственна за хорошую сочетаемость этого напитка с различной едой. Она продлевает послевкусие любой еды, делает нас более голодными и усиливает жажду с каждым новым глотком.
# - **volatile acidity (летучие кислоты)** – побочные продукты спиртового брожения. При брожении наименьшее количество летучих кислот образуется в интервале температур от 15 ºС до 25 ºС. Более высокие и более низкие температуры брожения способствуют образованию большей массы летучих кислот. Летучая кислотность – Показатель, характеризующий здоровье виноматериалов. Поэтому при их выдержке или хранении проводится периодический химический анализ вина. Летучая кислотность возрастает при окислении вина и в результате микробиальных заболеваний.
# - **citric acid (лимонная кислота)** - является продуктом брожения виноградного сусла или вина. Винной кислоты в вине может быть до 5,0 г/дм3. Содержание лимонной кислоты может быть до 2 г/дм3. В значительно больших количествах лимонная кислота есть в плодово-ягодных винах, где отсутствует винная кислота. Лимонную кислоту добавляют в вино при недостаточной кислотности, особенно в плодово-ягодном виноделии, так же в шампанском производстве при изготовлении ликеров.
# - **residual sugar (остаточный сахар)** - важно понимать, откуда в вине появился сахар. В подавляющем большинстве случаев его специально добавляют уже после завершения брожения. Зачастую это делается, чтобы прикрыть недостатки не слишком качественного виноматериала. На выходе получается простенькое и совершенно безликое полусладкое вино крепостью около 12 процентов, главным достоинством которого является низкая цена.Совсем другое дело, когда речь идет о так называемом остаточном сахаре, который изначально накапливается в ягоде, а при брожении не сбраживается до конца. Вина с таким сахаром называют натурально-сладкими. Они куда более сложные, редкие и дорогостоящие и, несомненно, заслуживают отдельного разговора.
# - **chlorides (хлориды)** - группа химических соединений, соли хлороводородной кислоты HCl Незначительное содержание хлора и хлоридов делает вино полезным при гипохлоридном режиме.
# - **free sulfur dioxide**
# - **total sulfur dioxide (диоксид серы SO2)** - важен в процессе виноделия, поскольку он помогает предотвратить рост микробов и окисление вина. Кроме того, известно, что SO2 и сульфирующие агенты являются аллергенами для многих людей, и по этой причине их уровни необходимо контролировать и регулировать в конечных винных продуктах.
# - **density (плотность)** - плотность вина может быть как меньше, так и больше плотности воды. Ее значение определяется в первую очередь концентрацией спирта и сахара. Белые, розовые и красные вина, как правило, легче воды — их плотность при температуре 20°С ниже 998,3 кг/м3.
# - **pH (активная кислотность или истинная кислотность)** – отрицательный логарифм концентрации водородных ионов выражается символом рН и является наиболее точной характеристикой кислотности сусла и вина.
# - **sulphates (сульфаты)** - необходимы, чтобы вино дольше хранилось. Для этого при обработке вина используют диоксид серы (E220). Диоксид серы это единственный консервант, который можно использовать при изготовлении вина
# - **alcohol (алкоголь)** - крепкость вина.
# - **quality** - оценка качества вина.

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1599, step=1)

# %% [markdown]
# ## **Столбец "citric acid"**

# %%
data['citric acid']
# Out:
# 0       0.00
# 1       0.00
# 2       0.04
# 3       0.56
# 4       0.00
# 5       0.00
# 6       0.06
# 7       0.00
# 8       0.02
# 9       0.36
# 10      0.08
# 11      0.36
# 12      0.00
# 13      0.29
# 14      0.18
# 15      0.19
# 16      0.56
# 17      0.28
# 18      0.08
# 19      0.51
# 20      0.48
# 21      0.31
# 22      0.21
# 23      0.11
# 24      0.14
# 25      0.16
# 26      0.24
# 27      0.21
# 28      0.00
# 29      0.00
#         ...
# 1569    0.14
# 1570    0.53
# 1571    0.14
# 1572    0.32
# 1573    0.20
# 1574    0.78
# 1575    0.40
# 1576    0.63
# 1577    0.15
# 1578    0.15
# 1579    0.09
# 1580    0.33
# 1581    0.09
# 1582    0.10
# 1583    0.29
# 1584    0.44
# 1585    0.44
# 1586    0.41
# 1587    0.11
# 1588    0.33
# 1589    0.20
# 1590    0.15
# 1591    0.09
# 1592    0.13
# 1593    0.08
# 1594    0.08
# 1595    0.10
# 1596    0.13
# 1597    0.12
# 1598    0.47
# Name: citric acid, Length: 1599, dtype: float64

# %% [markdown]
# ## **Значения в столбце "alcohol" не меньшие десяти**

# %%
data['alcohol'] >= 10
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7        True
# 8       False
# 9        True
# 10      False
# 11       True
# 12      False
# 13      False
# 14      False
# 15      False
# 16       True
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1569     True
# 1570     True
# 1571     True
# 1572    False
# 1573     True
# 1574     True
# 1575     True
# 1576     True
# 1577     True
# 1578     True
# 1579     True
# 1580     True
# 1581     True
# 1582     True
# 1583    False
# 1584     True
# 1585     True
# 1586     True
# 1587     True
# 1588     True
# 1589    False
# 1590     True
# 1591     True
# 1592     True
# 1593    False
# 1594     True
# 1595     True
# 1596     True
# 1597     True
# 1598     True
# ...

# %% [markdown]
# ## **Статистика по всем признакам**

# %%
data.describe(include = 'all')
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# ## **Корреляция между признаками**

# %%
data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# ## **Матрица ковариаций**

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(data, alpha = 0.1, figsize = (32, 32))
pass
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.

# %% [markdown]
# ## **График зависимоссти "fixed acidity" от "pH"**

# %%
plt.plot(data['fixed acidity'], data['pH'], 'o', alpha = 0.1)
plt.xlabel('fixed acidity')
plt.ylabel('pH')
pass

# %% [markdown]
# ## **Подготовка данных**

# %% [markdown]
# Делим признаки на категориальные и количественные:

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object'] 
numerical_columns = [c for c in data.columns if data[c].dtype.name != 'object'] 
print(categorical_columns) 
print(numerical_columns)
# Out:
# []
# ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']

# %% [markdown]
# Обработка пропущенных значений:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# Следует отсутствующих элементов нет.

# %% [markdown]
# ## **Нормализация количественных признаков**

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)
data_numerical.describe()
# Out:
#        fixed acidity  volatile acidity   citric acid  residual sugar  \
# count   1.599000e+03      1.599000e+03  1.599000e+03    1.599000e+03
# mean   -1.570643e-14     -1.590973e-15  6.045057e-15   -1.344696e-15
# std     1.000000e+00      1.000000e+00  1.000000e+00    1.000000e+00
# min    -2.136377e+00     -2.277567e+00 -1.391037e+00   -1.162333e+00
# 25%    -7.004996e-01     -7.696903e-01 -9.290275e-01   -4.530767e-01
# 50%    -2.410190e-01     -4.367545e-02 -5.634264e-02   -2.402999e-01
# 75%     5.056370e-01      6.264921e-01  7.650078e-01    4.340257e-02
# max     4.353787e+00      5.876138e+00  3.742403e+00    9.192806e+00
#
#           chlorides  free sulfur dioxide  total sulfur dioxide       density  \
# count  1.599000e+03         1.599000e+03          1.599000e+03  1.599000e+03
# mean   5.098590e-15        -7.724347e-17          1.619856e-16  3.772732e-13
# std    1.000000e+00         1.000000e+00          1.000000e+00  1.000000e+00
# ...

# %% [markdown]
# ## **Задаем X Y**

# %%
X = data_numerical.drop('quality', 1)
y = data_numerical['quality']

# %%
feature_names = X.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
feature_names
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (1599, 11)
# (1599,)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## **Тестовая и обучающая выборки**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape
N_test, _ = X_test.shape

print(N_train, N_test)
# Out:
# 1119 480

# %%
N_train + N_test
# Out:
# 1599

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # **KNN**

# %% [markdown]
# Предсказываем признак "quality", это задача восстановления регриссии.

# %%
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor(n_neighbors = 5)

# %%
knn
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform')

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform')

# %% [markdown]
# Подсчет средней ошибки:

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = 1 - knn.score(X_train, y_train)
err_test = 1 - knn.score(X_test, y_test)

print(err_train, err_test)
# Out:
# 0.485904749434 0.71882200727

# %% [markdown]
# Ошибка на обучающей выборке 48%, на тестовой выборке 71%.

# %% [markdown]
# ## **Подбор параметров**

# %% [markdown]
# Найдем такое значение параметра число соседей, при котором значение ошибки будет минимальным.

# %%
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15]
knn_r = KNeighborsRegressor()
grid = GridSearchCV(knn_r, param_grid = {'n_neighbors': nnb}, cv = 10)
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# 0.678409456428 15

# %% [markdown]
# Посчитаем ошибки на тестовой и обучающей выборке при подобранном параметре k = 15.

# %%
knn = KNeighborsRegressor(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train = 1 - knn.score(X_train, y_train)
err_test = 1 - knn.score(X_test, y_test)

print(err_train, err_test)
# Out:
# 0.590718020467 0.702436352932

# %% [markdown]
# Ошибка на обучающей выборке 59%, на тестовой выборке 70%. Присутствует переобучение.

# %% [markdown]
# # ***Задание №4***

# %% [markdown]
# ## **Обучаем регрессор**

# %% [markdown]
# Проведем задачу классификации 12 различных форм зданий с помощью нейронных сетей. Разобъем данные на тестовую и обучающую выборки.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)
N_test, _ = X_test.shape

# %% [markdown]
# Активационная функций: логистическая сигмоидальная f(x) = 1 / (1 + exp(-x)).

# %%
from sklearn.neural_network import MLPRegressor
mlp_model = MLPRegressor(hidden_layer_sizes = (100, ), solver = 'lbfgs', activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)
# Out:
# MLPRegressor(activation='logistic', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %% [markdown]
# Проверим качество регрессора по величине ошибки на тестовой и обучающей выборках.

# %%
print(1 - mlp_model.score(X_train, y_train), 1 - mlp_model.score(X_test, y_test))
# Out:
# 0.399821952076 0.61827480982

# %% [markdown]
# Ошибка на обучающей выборке 40%, на тестовой 61%.

# %% [markdown]
# Теперь возьмем два слоя, по шесть нейронов.

# %%
mlp_model = MLPRegressor(hidden_layer_sizes = (6, ), solver = 'lbfgs', activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)
# Out:
# MLPRegressor(activation='logistic', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(6,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %% [markdown]
# Проверим качество регрессора по величине ошибки на тестовой и обучающей выборках.

# %%
print(1 - mlp_model.score(X_train, y_train), 1 - mlp_model.score(X_test, y_test))
# Out:
# 0.504170683531 0.633418532363

# %% [markdown]
# Ошибка на обучающей выборке 50%, на тестовой 63%. Переобучения не наблюдается.

# %% [markdown]
# ## **Подбор alpha**

# %% [markdown]
# Найдем оптимальное значение параметра регуляризации alpha.

# %%
alpha_arr = np.logspace(-4, 5, 25)
test_err = []
train_err = []
for alpha in alpha_arr:
    mlp_model = MLPRegressor(alpha = alpha, hidden_layer_sizes = (6,), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    train_err.append(1 - mlp_model.score(X_train, y_train))
    test_err.append(1 - mlp_model.score(X_test, y_test))

# %%
plt.semilogx(alpha_arr, train_err, 'b-o', label = 'test')
plt.semilogx(alpha_arr, test_err, 'r-o', label = 'train')
plt.xlim([np.max(alpha_arr), np.min(alpha_arr)])
plt.title('Error vs alpha')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Минимальные значения ошибок:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.497233881225 0.583947574726

# %% [markdown]
# Получаем, что наименьшая ошибка на обучающей выборке 50%, а на тестовой 58%.

# %%
alpha_opt = alpha_arr[test_err == min_test_err]
alpha_opt = alpha_opt[0]
print(alpha_opt)
# Out:
# 0.56234132519

# %% [markdown]
# Оптимальное значение alpha = 0.5623.

# %% [markdown]
# ## **Подбор оптимального числа нейронов**

# %% [markdown]
# Найдем оптимальное число нейронов. Берем число слоев равным двум.

# %%
neurons_arr = np.arange(1, 100)
test_err = []
train_err = []
for neurons in neurons_arr:
    mlp_model = MLPRegressor(hidden_layer_sizes = (neurons, ), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    train_err.append(1 - mlp_model.score(X_train, y_train))
    test_err.append(1 - mlp_model.score(X_test, y_test))

# %%
plt.plot(neurons_arr, train_err, 'b-o', label = 'train')
plt.plot(neurons_arr, test_err, 'r-o', label = 'test')
plt.xlim([np.max(neurons_arr), np.min(neurons_arr)])
plt.title('Error vs neurons count')
plt.xlabel('neurons count')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Минимальные значения ошибок:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.29129873962 0.616597493539

# %% [markdown]
# Получаем, что наименьшая ошибка на обучающей выборке 29%, а на тестовой 61%.

# %%
neurons_opt = neurons_arr[test_err == min_test_err]
neurons_opt = neurons_opt[0]
print(neurons_opt)
# Out:
# 10

# %% [markdown]
# Оптимальное число нейронов - 10.

# %% [markdown]
# # ***Задание №5***

# %% [markdown]
# ## **Random forests**

# %% [markdown]
# Делим данные. Тестовая выборка составит 33% от общего количества.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
from sklearn import ensemble
rf = ensemble.RandomForestRegressor(n_estimators = 5)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# Проверим качество регрессора по величине ошибки на тестовой и обучающей выборках.

# %%
print(1 - mlp_model.score(X_train, y_train), 1 - mlp_model.score(X_test, y_test))
# Out:
# 0.455136825528 0.616597493539

# %% [markdown]
# Строим график зависимости ошибки на тестовой и обучающей выборках, и oob-ошибки от количества деревьев.

# %%
tree_arr = np.arange(1, 20, 5)
test_err = []
train_err = []
oob_err = []

for tree in tree_arr:
    rf = ensemble.RandomForestRegressor(n_estimators = tree, oob_score = True)
    rf.fit(X_train, y_train)
    train_err.append(1 - rf.score(X_train, y_train))
    test_err.append(1 - rf.score(X_test, y_test)) 
    oob_err.append(1 - rf.oob_score_)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:720: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:720: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:720: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:720: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
# ...

# %%
plt.plot(tree_arr, train_err, 'b-o', label = 'train')
plt.plot(tree_arr, test_err, 'r-o', label = 'test')
plt.plot(tree_arr, oob_err, 'g-o', label = 'oob')
plt.xlim([np.min(tree_arr), np.max(tree_arr)])
plt.title('Error vs. Count of tree')
plt.xlabel('Count of tree')
plt.ylabel('Error')
plt.legend()
pass

# %% [markdown]
# На графике переобучения не наблюдается.

# %% [markdown]
# Минимальные значения ошибок:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.0985740714902 0.59420752019

# %% [markdown]
# Получаем, что наименьшая ошибка на обучающей выборке 10%, а на тестовой 60%.

# %%
tree_opt = tree_arr[test_err == min_test_err]
tree_opt = tree_opt[0]
print(tree_opt)
# Out:
# 16

# %% [markdown]
# Оптимальное количество деревьев - 16.

# %% [markdown]
# ## **AdaBoost**

# %% [markdown]
# Обучим регрессор вида AdaBoost. Число регрессоров возьмем равным пяти.

# %%
ab = ensemble.AdaBoostRegressor(n_estimators = 5)
ab.fit(X_train, y_train)
# Out:
# AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#          n_estimators=5, random_state=None)

# %% [markdown]
# Проверим качество регрессора по величине ошибки на тестовой и обучающей выборках.

# %%
err_train = 1 - knn.score(X_train, y_train)
err_test = 1 - knn.score(X_test, y_test)
print(err_train, err_test)
# Out:
# 0.49241977408 0.675618530736

# %% [markdown]
# Ошибка на обучающей выборке 49%, на тестовой 68%.

# %% [markdown]
# Строим график зависимости ошибки на тестовой и обучающей выборках от количества деревьев.

# %%
estimator_arr = np.arange(1, 200, 1)
test_err = []
train_err = []
for estimator in estimator_arr:
    ab = ensemble.AdaBoostRegressor(n_estimators = estimator)
    ab.fit(X_train, y_train)
    train_err.append(1 - ab.score(X_train, y_train))
    test_err.append(1 - ab.score(X_test, y_test))

# %%
plt.plot(estimator_arr, train_err, 'b-o', label = 'train')
plt.plot(estimator_arr, test_err, 'r-o', label = 'test')
plt.xlim([np.min(estimator_arr), np.max(estimator_arr)])
plt.title('Error vs. Count of estimator')
plt.xlabel('Count of estimator')
plt.ylabel('Error')
plt.legend()
pass

# %% [markdown]
# Минимальные значения ошибок:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.495668241845 0.601920982356

# %% [markdown]
# Получаем, что наименьшая ошибка на обучающей выборке 50%, а на тестовой 60%.

# %%
trees_opt = estimator_arr[test_err == min_test_err]
trees_opt = trees_opt[0]
print(trees_opt)
# Out:
# 81

# %% [markdown]
# Оптимальное число классификаторов - 81.

# %% [markdown]
# ## **Gradient boosted trees**

# %% [markdown]
# Обучим регрессор вида Gradient boosted trees. Число деревьев возьмем равным пяти.

# %%
gbt = ensemble.GradientBoostingRegressor(n_estimators = 5)
gbt.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=5, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)

# %% [markdown]
# Проверим качество регрессора по величине ошибки на тестовой и обучающей выборках.

# %%
err_train = 1 - knn.score(X_train, y_train)
err_test = 1 - knn.score(X_test, y_test)
print(err_train, err_test)
# Out:
# 0.49241977408 0.675618530736

# %% [markdown]
# Ошибка на обучающей выборке 49%, на тестовой 68%.

# %% [markdown]
# Строим график зависимости ошибки на тестовой и обучающей выборках от количества деревьев.

# %%
tree_arr = np.arange(1, 100, 5)
test_err = []
train_err = []
for tree in tree_arr:
    gbt = ensemble.GradientBoostingRegressor(n_estimators = tree)
    gbt.fit(X_train, y_train)
    train_err.append(1 - gbt.score(X_train, y_train))
    test_err.append(1 - gbt.score(X_test, y_test))

# %%
plt.plot(tree_arr, train_err, 'b-o', label = 'train')
plt.plot(tree_arr, test_err, 'r-o', label = 'test')
plt.xlim([np.min(tree_arr), np.max(tree_arr)])
plt.title('Error vs. number of trees')
plt.xlabel('Number of trees')
plt.ylabel('Error')
plt.legend()
pass

# %% [markdown]
# Присутствует переобучение.

# %% [markdown]
# Минимальные значения ошибок:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.346178873081 0.632408922676

# %% [markdown]
# Получаем, что наименьшая ошибка на обучающей выборке 35%, а на тестовой 63%.

# %%
trees_opt = tree_arr[test_err == min_test_err]
trees_opt = trees_opt[0]
print(trees_opt)
# Out:
# 56

# %% [markdown]
# Оптимальное количество деревьев - 56.

# %% [markdown]
# ## **Extremely Randomized Trees**

# %%
ert = ensemble.ExtraTreesRegressor(n_estimators = 10)
ert.fit(X_train, y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=None,
#           max_features='auto', max_leaf_nodes=None,
#           min_impurity_decrease=0.0, min_impurity_split=None,
#           min_samples_leaf=1, min_samples_split=2,
#           min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#           oob_score=False, random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# Ошибки:

# %%
err_train = 1 - knn.score(X_train, y_train)
err_test = 1 - knn.score(X_test, y_test)
print(err_train, err_test)
# Out:
# 0.49241977408 0.675618530736

# %% [markdown]
# Ошибка на обучающей выборке 49%, на тестовой 68%.

# %% [markdown]
# Строим график зависимости ошибки на тестовой и обучающей выборках, и oob-ошибки от количества деревьев

# %%
tree_arr = np.arange(1, 20, 5)
test_err = []
train_err = []
oob_err = []
for tree in tree_arr:
    ert = ensemble.ExtraTreesRegressor(n_estimators = tree, oob_score=True, bootstrap=True, max_depth=7)
    ert.fit(X_train, y_train)
    train_err.append(1 - ert.score(X_train, y_train))
    test_err.append(1 - ert.score(X_test, y_test)) 
    oob_err.append(1 - ert.oob_score_)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:720: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:720: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:720: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:720: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
# ...

# %%
plt.plot(tree_arr, train_err, 'b-o', label = 'train')
plt.plot(tree_arr, test_err, 'r-o', label = 'test')
plt.plot(tree_arr, oob_err, 'y-o', label = 'oob')
plt.xlim([np.min(tree_arr), np.max(tree_arr)])
plt.title('Error vs. Count of tree')
plt.xlabel('Count of tree')
plt.ylabel('Error')
plt.legend()
pass

# %% [markdown]
# Присутствует переобучение.

# %% [markdown]
# Минимальные значения ошибок:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.410417696052 0.61566327113

# %% [markdown]
# Получаем, что наименьшая ошибка на обучающей выборке 41%, а на тестовой 62%.

# %%
trees_opt = tree_arr[test_err == min_test_err]
trees_opt = trees_opt[0]
print(trees_opt)
# Out:
# 6

# %% [markdown]
# Оптимальное число деревьев - 6.

# %% [markdown]
# # ***Задача №7***

# %% [markdown]
# ## **PCA**

# %%
X1 = X

# %%
from sklearn.decomposition import PCA
pca = PCA( n_components = 7 ,svd_solver='full')
pca.fit(X1)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=7, random_state=None,
#   svd_solver='full', tol=0.0, whiten=False)

# %%
result=pca.transform(X1)

# %%
result.shape
# Out:
# (1599, 7)

# %%
type(pca)
# Out:
# sklearn.decomposition.pca.PCA

# %%
pca.explained_variance_
# Out:
# array([ 3.09913244,  1.92590969,  1.55054349,  1.21323253,  0.95929207,
#         0.65960826,  0.58379122])

# %%
pca.explained_variance_ratio_
# Out:
# array([ 0.28173931,  0.1750827 ,  0.1409585 ,  0.11029387,  0.08720837,
#         0.05996439,  0.05307193])

# %% [markdown]
# Главные компоненты.

# %%
pca.components_
# Out:
# array([[ 0.48931422, -0.23858436,  0.46363166,  0.14610715,  0.21224658,
#         -0.03615752,  0.02357485,  0.39535301, -0.43851962,  0.24292133,
#         -0.11323206],
#        [-0.11050274,  0.27493048, -0.15179136,  0.27208024,  0.14805156,
#          0.51356681,  0.56948696,  0.23357549,  0.00671079, -0.03755392,
#         -0.38618096],
#        [-0.12330157, -0.44996253,  0.23824707,  0.10128338, -0.09261383,
#          0.42879287,  0.3224145 , -0.33887135,  0.05769735,  0.27978615,
#          0.47167322],
#        [-0.22961737,  0.07895978, -0.07941826, -0.37279256,  0.66619476,
#         -0.04353782, -0.03457712, -0.17449976, -0.00378775,  0.55087236,
#         -0.12218109],
#        [-0.08261366,  0.21873452, -0.05857268,  0.73214429,  0.2465009 ,
#         -0.15915198, -0.22246456,  0.15707671,  0.26752977,  0.22596222,
#          0.35068141],
#        [ 0.10147858,  0.41144893,  0.06959338,  0.04915555,  0.30433857,
# ...

# %% [markdown]
# Ищем оптимальное количество главных компонент.

# %%
arr_comp=[]
pca_global = PCA( n_components = 8 ,svd_solver='full')
pca_global.fit(X1)
result_global=pca_global.transform(X1)
sum=0.0
for gl in pca_global.explained_variance_:
    sum+=gl

comp_arr = np.arange(2,9)
for opt in comp_arr:
    pca_comp = PCA( n_components = opt ,svd_solver='full')
    pca_comp.fit(X1)
    result_comp=pca_comp.transform(X1)
    sum_comp=0.0
    for gl in pca_comp.explained_variance_:
        sum_comp+=gl
    if (sum_comp/sum)>0.95: arr_comp.append(opt)

# %%
arr_comp
# Out:
# [7, 8]

# %%
ncomp_opt=arr_comp[0]
print(ncomp_opt)
# Out:
# 7

# %% [markdown]
# Наилучшее число компонент - 7.

# %%
ncomp_opt=arr_comp[0]
pca_opt = PCA( n_components = ncomp_opt ,svd_solver='full')
pca_opt.fit(X1)
result_opt=pca_opt.transform(X1)
X_train, X_test, y_train, y_test = train_test_split(result_opt, y, test_size = 0.33, random_state = 42)

# %% [markdown]
# Графики зависимости ошибок на тестовой и обучающей выборках, от количества деревьев. Регрессор вида AdaBoost.

# %%
estimator_arr = np.arange(1, 200, 5)
test_err = []
train_err = []
obb_err=[]
for estimator in estimator_arr:
    ab = ensemble.AdaBoostRegressor(n_estimators = estimator)
    ab.fit(X_train, y_train)
    train_err.append(1 - ab.score(X_train, y_train))
    test_err.append(1 - ab.score(X_test, y_test))
plt.plot(estimator_arr, train_err, 'b-o', label = 'train')
plt.plot(estimator_arr, test_err, 'r-o', label = 'test')
plt.xlim([np.min(estimator_arr), np.max(estimator_arr)])
plt.title('Error vs. Count of estimator')
plt.xlabel('Count of estimator')
plt.ylabel('Error')
plt.legend()
pass

# %% [markdown]
# Минимальные значения ошибок:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.554543162499 0.677041063656

# %% [markdown]
# Получаем, что на обучающей выборке минимальная ошибка 55%, на тестовой 68%.

# %%
trees_opt = estimator_arr[test_err == min_test_err]
print(trees_opt)
# Out:
# [171]

# %% [markdown]
# Оптимальное количество деревьев - 171.

# %% [markdown]
# Применим к данным PCA, и построим аналогичные графики.

# %%
test_err = []
train_err = []
for ncomp_opt in arr_comp:
    pca_opt = PCA( n_components = ncomp_opt ,svd_solver='full')
    pca_opt.fit(X1)
    result_opt=pca_opt.transform(X1)
    X_train, X_test, y_train, y_test = train_test_split(result_opt, y, test_size = 0.33, random_state = 42)
    ab = ensemble.AdaBoostRegressor(n_estimators = 150)
    ab.fit(X_train, y_train)
    train_err.append(1 - ab.score(X_train, y_train))
    test_err.append(1 - ab.score(X_test, y_test))
plt.plot(arr_comp, train_err, 'b-o', label = 'train')
plt.plot(arr_comp, test_err, 'r-o', label = 'test')
plt.xlim([np.min(arr_comp), np.max(arr_comp)])
plt.title('Error vs. Component')
plt.xlabel('Component')
plt.ylabel('Error')
plt.legend()
pass

# %% [markdown]
# Наблюдается переобучение. Ошибки перестали вести себя скачкообразно.

# %% [markdown]
# Минимальное значение ошибок:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.589923123431 0.700669932095

# %% [markdown]
# Получаем, что минимальная ошибка на обучающей выборке 59%, на тестовой 70%.

# %%
test_err = []
train_err = []
for ncomp_opt in comp_arr:
    pca_opt = PCA( n_components = ncomp_opt ,svd_solver='full')
    pca_opt.fit(X1)
    result_opt=pca_opt.transform(X1)
    X_train, X_test, y_train, y_test = train_test_split(result_opt, y, test_size = 0.33, random_state = 42)
    ab = ensemble.AdaBoostRegressor(n_estimators = 150)
    ab.fit(X_train, y_train)
    train_err.append(1 - ab.score(X_train, y_train))
    test_err.append(1 - ab.score(X_test, y_test))
plt.plot(comp_arr, train_err, 'b-o', label = 'train')
plt.plot(comp_arr, test_err, 'r-o', label = 'test')
plt.xlim([np.min(comp_arr), np.max(comp_arr)])
plt.title('Error vs. Component')
plt.xlabel('Component')
plt.ylabel('Error')
plt.legend()
pass

# %% [markdown]
# Минимальные значения ошибок:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.579683886868 0.688753995457

# %% [markdown]
# Получаем, что минимальная ошибка на обучающей выборке 58%, на тестовой 69%.

# %% [markdown]
# Наилучшее значение количества используемых главных компонент.

# %%
print(comp_arr[test_err == min_test_err])
# Out:
# [3]
